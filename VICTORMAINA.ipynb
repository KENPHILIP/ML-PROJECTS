# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import accuracy_score

# %%
data=pd.read_csv('C:/Users/VICKFURY/Documents/Python Scripts/ml/datasets/data.csv')

# %%
data.head(20)
# Out:
#                    date      price  bedrooms  bathrooms  sqft_living  \
# 0   2014-05-02 00:00:00   313000.0       3.0       1.50         1340
# 1   2014-05-02 00:00:00  2384000.0       5.0       2.50         3650
# 2   2014-05-02 00:00:00   342000.0       3.0       2.00         1930
# 3   2014-05-02 00:00:00   420000.0       3.0       2.25         2000
# 4   2014-05-02 00:00:00   550000.0       4.0       2.50         1940
# 5   2014-05-02 00:00:00   490000.0       2.0       1.00          880
# 6   2014-05-02 00:00:00   335000.0       2.0       2.00         1350
# 7   2014-05-02 00:00:00   482000.0       4.0       2.50         2710
# 8   2014-05-02 00:00:00   452500.0       3.0       2.50         2430
# 9   2014-05-02 00:00:00   640000.0       4.0       2.00         1520
# 10  2014-05-02 00:00:00   463000.0       3.0       1.75         1710
# 11  2014-05-02 00:00:00  1400000.0       4.0       2.50         2920
# 12  2014-05-02 00:00:00   588500.0       3.0       1.75         2330
# ...

# %%
data.isnull().sum()
data.describe()
# Out:
#               price     bedrooms    bathrooms   sqft_living      sqft_lot  \
# count  4.600000e+03  4600.000000  4600.000000   4600.000000  4.600000e+03
# mean   5.519630e+05     3.400870     2.160815   2139.346957  1.485252e+04
# std    5.638347e+05     0.908848     0.783781    963.206916  3.588444e+04
# min    0.000000e+00     0.000000     0.000000    370.000000  6.380000e+02
# 25%    3.228750e+05     3.000000     1.750000   1460.000000  5.000750e+03
# 50%    4.609435e+05     3.000000     2.250000   1980.000000  7.683000e+03
# 75%    6.549625e+05     4.000000     2.500000   2620.000000  1.100125e+04
# max    2.659000e+07     9.000000     8.000000  13540.000000  1.074218e+06
#
#             floors   waterfront         view    condition   sqft_above  \
# count  4600.000000  4600.000000  4600.000000  4600.000000  4600.000000
# mean      1.512065     0.007174     0.240652     3.451739  1827.265435
# std       0.538288     0.084404     0.778405     0.677230   862.168977
# ...

# %%
data.corr()
# Out:
#                   price  bedrooms  bathrooms  sqft_living  sqft_lot    floors  \
# price          1.000000  0.200336   0.327110     0.430410  0.050451  0.151461
# bedrooms       0.200336  1.000000   0.545920     0.594884  0.068819  0.177895
# bathrooms      0.327110  0.545920   1.000000     0.761154  0.107837  0.486428
# sqft_living    0.430410  0.594884   0.761154     1.000000  0.210538  0.344850
# sqft_lot       0.050451  0.068819   0.107837     0.210538  1.000000  0.003750
# floors         0.151461  0.177895   0.486428     0.344850  0.003750  1.000000
# waterfront     0.135648 -0.003483   0.076232     0.117616  0.017241  0.022024
# view           0.228504  0.111028   0.211960     0.311009  0.073907  0.031211
# condition      0.034915  0.025080  -0.119994    -0.062826  0.000558 -0.275013
# sqft_above     0.367570  0.484705   0.689918     0.876443  0.216455  0.522814
# sqft_basement  0.210427  0.334165   0.298020     0.447206  0.034842 -0.255510
# ...

# %%
fig,ax=plt.subplots(figsize=(10,10))
heatmap1=sns.heatmap(data.corr(),annot=True,ax=ax)

# %%
heatmap1
# Out:
# <AxesSubplot:>

# %%
data.dtypes
data.columns
# Out:
# Index(['date', 'price', 'bedrooms', 'bathrooms', 'sqft_living', 'sqft_lot',
#        'floors', 'waterfront', 'view', 'condition', 'sqft_above',
#        'sqft_basement', 'yr_built', 'yr_renovated', 'street', 'city',
#        'statezip', 'country'],
#       dtype='object')

# %%
y=data['price']

# %%
x=data.drop(['date', 'price', 'yr_built', 'yr_renovated', 'street', 'city',
       'statezip', 'country'], axis =1)

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test= train_test_split(x,y,test_size=0.3,random_state=100)

# %%
from sklearn.linear_model import LinearRegression

# %%
our_model=LinearRegression()
our_model.fit(x_train,y_train)
# our_model.fit(x_test,y_test)
y_train
# Out:
# 2867    4.400000e+05
# 3748    1.695000e+06
# 4475    4.586639e+05
# 428     5.660000e+05
# 474     9.270000e+05
#             ...
# 4149    4.050000e+05
# 1890    5.320000e+05
# 350     3.580000e+05
# 79      7.053800e+05
# 3927    3.950000e+05
# Name: price, Length: 3220, dtype: float64

# %%
preds=our_model.predict(x_train)
print(preds)
# Out:
# [ 342224.89059999 1148128.90318361  388166.20563405 ...  293873.23620581
#   647017.10565339  448806.14751431]

# %%
training_accuracy=accuracy_score(y_train,preds)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-31-63c6307c1abb> in <module>
# ----> 1 training_accuracy=accuracy_score(y_train,preds)
#
# ~\anaconda3\lib\site-packages\sklearn\utils\validation.py in inner_f(*args, **kwargs)
#      61             extra_args = len(args) - len(all_args)
#      62             if extra_args <= 0:
# ---> 63                 return f(*args, **kwargs)
#      64
#      65             # extra_args > 0
#
# ~\anaconda3\lib\site-packages\sklearn\metrics\_classification.py in accuracy_score(y_true, y_pred, normalize, sample_weight)
#     200
#     201     # Compute accuracy for each possible representation
# --> 202     y_type, y_true, y_pred = _check_targets(y_true, y_pred)
#     203     check_consistent_length(y_true, y_pred, sample_weight)
#     204     if y_type.startswith('multilabel'):
#
# ...

# %%
preds2=our_model.predict(x_test)
print(preds2)
# Out:
# [508021.47845643 437031.6002106  903074.69511273 ... 608752.38855274
#  566534.76165403 457275.91520986]

# %%
plt.scatter(y_train,preds)

# %%
from sklearn.metrics import r2_score
r2_score(preds2,y_test)
# Out:
# -0.11124733789375862

# %%
from sklearn import metrics
metrics.mean_absolute_error(preds,y_test)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-18-2bc8dda53a24> in <module>
#       1 from sklearn import metrics
# ----> 2 metrics.mean_absolute_error(preds,y_test)
#
# ~\anaconda3\lib\site-packages\sklearn\utils\validation.py in inner_f(*args, **kwargs)
#      61             extra_args = len(args) - len(all_args)
#      62             if extra_args <= 0:
# ---> 63                 return f(*args, **kwargs)
#      64
#      65             # extra_args > 0
#
# ~\anaconda3\lib\site-packages\sklearn\metrics\_regression.py in mean_absolute_error(y_true, y_pred, sample_weight, multioutput)
#     180     0.85...
#     181     """
# --> 182     y_type, y_true, y_pred, multioutput = _check_reg_targets(
#     183         y_true, y_pred, multioutput)
#     184     check_consistent_length(y_true, y_pred, sample_weight)
#
# ...

# %%
import pickle
model ="housepredictionmodel.pkl"
pickle.dump(our_model,open(model,"wb"))
